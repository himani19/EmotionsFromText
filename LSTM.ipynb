# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import string
import nltk
nltk.download('stopwords')
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /home/priya/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#read the data set
data = pd.read_csv("./Data/phrases.csv")
data=data.dropna()
# print type(data)
print data['Emotion'].unique()
# Out:
# ['joy' 'fear' 'anger' 'sadness' 'disgust' 'shame' 'guilt']

# %% [markdown]
# ## We are applying an LSTM based model for the emotion prediction. a special kind of RNN, capable of learning long-term dependencies.

# %% [markdown]
# ## Preprocess the data set via cleaning, tokenisation and lemmatization

# %%
# print data
def clean_dataset(data):
    translator = string.maketrans('', '')
    for index,row in data.iterrows():
        row['Phrase'] = row['Phrase'].replace('[','')
        row['Phrase'] = row['Phrase'].replace(']','')
        row['Phrase'] = row['Phrase'].strip()
        row['Phrase'] = row['Phrase'].translate(translator,string.punctuation)
    return data
data = clean_dataset(data)
print data.head()
# Out:
#    Emotion                                             Phrase
# 0      joy  On days when I feel closing to my partner and ...
# 1     fear  Every time I imagine that someone I love or I ...
# 2    anger  When I had been obviously unjustly treated and...
# 3  sadness  When I think about the short time that we live...
# 4  disgust  At a gathering I found myself involuntarily si...

# %%
def tokenise(data):
    ## Convert words to lower case and split them    
    ## Remove stop words
    stops = set(stopwords.words("english"))
    
    for index,row in data.iterrows():
        text = row['Phrase'].lower().split(' ')
        text = [w.strip() for w in text if not w in stops and len(w) >= 2]
        text = " ".join(text)
        row['Phrase'] = text
    # split the dataset into tokens
    return data
data = tokenise(data)
data.head()
# Out:
#    Emotion                                             Phrase
# 0      joy  days feel closing partner friends when feel pe...
# 1     fear  every time imagine someone love could contact ...
# 2    anger  obviously unjustly treated possibility of eluc...
# 3  sadness  think short time live relate the periods life ...
# 4  disgust  gathering found involuntarily sitting next two...

# %%
def lemmatization(dataset):
    stemmer = SnowballStemmer('english')
    list_of_words=[]
    for index,row in dataset.iterrows():
        text = row['Phrase'].split()
        stemmed_words = [stemmer.stem(word) for word in text]
        list_of_words.append(stemmed_words)
        text = " ".join(stemmed_words)
        row['Phrase'] = text
    data['list_of_words'] = list_of_words
    return dataset
data = lemmatization(data)
data
# Out:
#       Emotion                                             Phrase  \
# 0         joy  day feel close partner friend when feel peac a...
# 1        fear  everi time imagin someon love could contact se...
# 2       anger             obvious unjust treat possibl of elucid
# 3     sadness  think short time live relat the period life th...
# 4     disgust  gather found involuntarili sit next two peopl ...
# 5       shame  realiz direct feel discont with partner way tr...
# 6       guilt  feel guilti realiz consid materi thing more im...
# 7         joy            girlfriend taken exam went parent place
# 8        fear                       first time realiz mean death
# 9       anger                  car overtak anoth forc drive road
# 10    sadness  recent thought hard work take studi how one wa...
# 11    disgust                       found bristl liver past tube
# 12      shame  tire unmotiv shout girlfriend and brought nega...
# 13      guilt  think studi enough weekend think abl accomplis...
# 14        joy                             pass examin think well
# 15       fear  one arrang meet someon person arriv late meant...
# 16      anger                   one unjust accus someth one done
# 17    sadness       one studi seem hopeless difficult uninterest
# 18    disgust  one find someon know like one had thought inst...
# 19      shame                one unjust stupid toward someon els
# 20      guilt                     one neglect unjust good friend
# 21        joy                              pass exam expect pass
# 22       fear  climb tree pick appl angl ladder i enabl get h...
# 23      anger                                 friend tortur anim
# 24    sadness                                              anger
# 25    disgust                                 friend tortur anim
# 26      shame                                 friend tortur anim
# 27      guilt                                excus necessari get
# 28        joy                                           children
# 29       fear  year old son climb sat 7th floor balconi leg h...
# ...       ...                                                ...
# 7622    shame                     forgot zip trouser notic anyon
# 7623    guilt                                               peep
# 7624      joy                 picnic old classmat chat play game
# 7625     fear  night alon home famili member usual get togeth...
# 7626    anger  saw bed hostel mess guess someon els use daili...
# 7627  sadness  physic experi session understand content exper...
# 7628  disgust  man sexual aggress small girl bus girl not dar...
# 7629    shame                                unabl stop urin bus
# 7630    guilt  old peopl crowd bus courag give seat close eye...
# 7631      joy  first time gave birthday present friend wrote ...
# 7632     fear  week higher level result announc had tri fail ...
# 7633    anger  surnam brother differ often grin home provok o...
# 7634  sadness  primari father die young and know happen weep ...
# 7635  disgust  hostel roommat selfish person would avoid do a...
# 7636    shame  friend mani femal friend thought his lover wou...
# 7637    guilt  past use think mother nag person start live ho...
# 7638      joy  august1983 long await big envelop document cuh...
# 7639     fear  christma eve1984 finish exam afraid result one...
# 7640    anger  septemb 1984 forc live someon like first week ...
# 7641  sadness  issu worri rather sadden mid septemb i went gu...
# 7642  disgust  roommat like listen meaningless song melodi co...
# 7643    shame  last summer went camp cu student work leav sec...
# 7644    guilt                                lie one best friend
# 7645      joy                       receiv letter distant friend
# 7646     fear  parent eldest home midnight male stranger phon...
# 7647    anger  two year back someon invit tutor granddaught g...
# 7648  sadness  taken respons someth prepar howev fail timid t...
# 7649  disgust  home heard loud sound spit outsid door thought...
# 7650    shame           homework teacher ask us was scold immedi
# 7651    guilt     shout younger brother alway afraid i call loud
#
#                                           list_of_words
# 0     [day, feel, close, partner, friend, when, feel...
# 1     [everi, time, imagin, someon, love, could, con...
# 2         [obvious, unjust, treat, possibl, of, elucid]
# 3     [think, short, time, live, relat, the, period,...
# 4     [gather, found, involuntarili, sit, next, two,...
# 5     [realiz, direct, feel, discont, with, partner,...
# 6     [feel, guilti, realiz, consid, materi, thing, ...
# 7        [girlfriend, taken, exam, went, parent, place]
# 8                    [first, time, realiz, mean, death]
# 9              [car, overtak, anoth, forc, drive, road]
# 10    [recent, thought, hard, work, take, studi, how...
# 11                   [found, bristl, liver, past, tube]
# 12    [tire, unmotiv, shout, girlfriend, and, brough...
# 13    [think, studi, enough, weekend, think, abl, ac...
# 14                          [pass, examin, think, well]
# 15    [one, arrang, meet, someon, person, arriv, lat...
# 16              [one, unjust, accus, someth, one, done]
# 17    [one, studi, seem, hopeless, difficult, uninte...
# 18    [one, find, someon, know, like, one, had, thou...
# 19           [one, unjust, stupid, toward, someon, els]
# 20                 [one, neglect, unjust, good, friend]
# 21                           [pass, exam, expect, pass]
# 22    [climb, tree, pick, appl, angl, ladder, i, ena...
# 23                               [friend, tortur, anim]
# 24                                              [anger]
# 25                               [friend, tortur, anim]
# 26                               [friend, tortur, anim]
# 27                              [excus, necessari, get]
# 28                                           [children]
# 29    [year, old, son, climb, sat, 7th, floor, balco...
# ...                                                 ...
# 7622               [forgot, zip, trouser, notic, anyon]
# 7623                                             [peep]
# 7624          [picnic, old, classmat, chat, play, game]
# 7625  [night, alon, home, famili, member, usual, get...
# 7626  [saw, bed, hostel, mess, guess, someon, els, u...
# 7627  [physic, experi, session, understand, content,...
# 7628  [man, sexual, aggress, small, girl, bus, girl,...
# 7629                           [unabl, stop, urin, bus]
# 7630  [old, peopl, crowd, bus, courag, give, seat, c...
# 7631  [first, time, gave, birthday, present, friend,...
# 7632  [week, higher, level, result, announc, had, tr...
# 7633  [surnam, brother, differ, often, grin, home, p...
# 7634  [primari, father, die, young, and, know, happe...
# 7635  [hostel, roommat, selfish, person, would, avoi...
# 7636  [friend, mani, femal, friend, thought, his, lo...
# 7637  [past, use, think, mother, nag, person, start,...
# 7638  [august1983, long, await, big, envelop, docume...
# 7639  [christma, eve1984, finish, exam, afraid, resu...
# 7640  [septemb, 1984, forc, live, someon, like, firs...
# 7641  [issu, worri, rather, sadden, mid, septemb, i,...
# 7642  [roommat, like, listen, meaningless, song, mel...
# 7643  [last, summer, went, camp, cu, student, work, ...
# 7644                           [lie, one, best, friend]
# 7645                  [receiv, letter, distant, friend]
# 7646  [parent, eldest, home, midnight, male, strange...
# 7647  [two, year, back, someon, invit, tutor, grandd...
# 7648  [taken, respons, someth, prepar, howev, fail, ...
# 7649  [home, heard, loud, sound, spit, outsid, door,...
# 7650   [homework, teacher, ask, us, was, scold, immedi]
# 7651  [shout, younger, brother, alway, afraid, i, ca...
#
# [7652 rows x 3 columns]

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Flatten, LSTM, Conv1D, MaxPooling1D, Dropout, Activation
from keras.layers.embeddings import Embedding
vocabulary_size = 20000
tokenizer = Tokenizer(num_words= vocabulary_size)
tokenizer.fit_on_texts(data['Phrase'])

sequences = tokenizer.texts_to_sequences(data['Phrase'])
tokenized_data = pad_sequences(sequences, maxlen=50)
# tokenized_data
# Out:
# Using TensorFlow backend.

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')
X = data['Emotion'].unique()
# print X
X=X.reshape(-1,1)
# print X
enc.fit(X)
enc.categories_
emotion_data=data['Emotion'].values
emotion_data=emotion_data.reshape(-1,1)
emotion_data=enc.transform(emotion_data).toarray()

# %%
train_phrase, validate_phrase = np.split(tokenized_data,[int(.8*len(tokenized_data))])
test_t,test_v = np.split(data['Phrase'],[int(.8*len(data['Phrase']))])
train_label,validate_emotion=np.split(emotion_data,[int(.8*len(emotion_data))])
# train_label

# %%
model = Sequential()
model.add(Embedding(20000, 100, input_length=50))
model.add(LSTM(100, dropout=0.2, return_sequences=True, recurrent_dropout=0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(7, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(train_phrase, np.array(train_label), epochs=5,  validation_data=(validate_phrase, validate_emotion))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 6121 samples, validate on 1531 samples
# Epoch 1/5
# 6121/6121 [==============================] - 44s 7ms/step - loss: 1.7932 - acc: 0.2710 - val_loss: 1.5003 - val_acc: 0.4442
# Epoch 2/5
# 6121/6121 [==============================] - 37s 6ms/step - loss: 1.1854 - acc: 0.5718 - val_loss: 1.3330 - val_acc: 0.5049
# Epoch 3/5
# 6121/6121 [==============================] - 37s 6ms/step - loss: 0.8456 - acc: 0.7045 - val_loss: 1.3689 - val_acc: 0.5212
# Epoch 4/5
# 6121/6121 [==============================] - 37s 6ms/step - loss: 0.6448 - acc: 0.7804 - val_loss: 1.5450 - val_acc: 0.5147
# Epoch 5/5
# 6121/6121 [==============================] - 37s 6ms/step - loss: 0.5288 - acc: 0.8268 - val_loss: 1.6231 - val_acc: 0.5225

# %%
predicted_emo=model.predict(validate_phrase)

# %%
test=(enc.inverse_transform(predicted_emo)).reshape(-1)
actual = (enc.inverse_transform(validate_emotion)).reshape(-1)
test
# Out:
# array(['shame', 'anger', 'sadness', ..., 'disgust', 'shame', 'fear'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(actual,test)
# Out:
# 0.5225342913128674

# %%
def data_preprocess(text):
#     cleaning
    translator = string.maketrans('', '')
    text = text.replace('[','')
    text = text.replace(']','')
    text = text.strip()
    text = text.translate(translator,string.punctuation)
#     stop word removal
    stops = set(stopwords.words("english"))
    text = text.lower().split(' ')
    text = [w.strip() for w in text if not w in stops and len(w) >= 2]
    text = " ".join(text)
#     lemmatization
    stemmer = SnowballStemmer('english')
    text = text.split()
    stemmed_words = [stemmer.stem(word) for word in text]
    text = " ".join(stemmed_words)
    
    return text

# %%
sequences = tokenizer.texts_to_sequences([data_preprocess('I am happy!')])
test_data = pad_sequences(sequences, maxlen=50)
pred_emo = model.predict(test_data)
test_op = (enc.inverse_transform(pred_emo)).reshape(-1)
test_op
# Out:
# array(['joy'], dtype=object)
