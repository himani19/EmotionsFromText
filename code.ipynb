# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import string
import nltk
nltk.download('stopwords')
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /home/priya/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# normalisation of the dataset
def normalize(X):
    from sklearn.preprocessing import StandardScaler
    X = StandardScaler().fit_transform(X)
    return X

# %%
#read the data set
data = pd.read_csv("./Data/phrases.csv")
# data=pd.DataFrame(data)
# print type(data)
print data['Emotion'].unique()
# Out:
# ['joy' 'fear' 'anger' 'sadness' 'disgust' 'shame' 'guilt']

# %% [markdown]
# ## We are applying an LSTM based model for the emotion prediction. a special kind of RNN, capable of learning long-term dependencies.

# %% [markdown]
# ## Preprocess the data set via cleaning, tokenisation and lemmatization

# %%
# print data
def clean_dataset(data):
    translator = string.maketrans('', '')
    for index,row in data.iterrows():
        row['Phrase'] = row['Phrase'].replace('[','')
        row['Phrase'] = row['Phrase'].replace(']','')
        row['Phrase'] = row['Phrase'].strip()
        row['Phrase'] = row['Phrase'].translate(translator,string.punctuation)
    return data
data = clean_dataset(data)
print data.head()
# Out:
#    Emotion                                             Phrase
# 0      joy  On days when I feel closing to my partner and ...
# 1     fear  Every time I imagine that someone I love or I ...
# 2    anger  When I had been obviously unjustly treated and...
# 3  sadness  When I think about the short time that we live...
# 4  disgust  At a gathering I found myself involuntarily si...

# %%
def tokenise(data):
    ## Convert words to lower case and split them    
    ## Remove stop words
    stops = set(stopwords.words("english"))
    
    for index,row in data.iterrows():
        text = row['Phrase'].lower().split(' ')
        text = [w.strip() for w in text if not w in stops and len(w) >= 2]
        text = " ".join(text)
    # split the dataset into tokens
    return data
data = tokenise(data)
data.head()
# Out:
#    Emotion                                             Phrase
# 0      joy  On days when I feel closing to my partner and ...
# 1     fear  Every time I imagine that someone I love or I ...
# 2    anger  When I had been obviously unjustly treated and...
# 3  sadness  When I think about the short time that we live...
# 4  disgust  At a gathering I found myself involuntarily si...

# %%
def lemmatization(dataset):
    stemmer = SnowballStemmer('english')
    list_of_words=[]
    for index,row in dataset.iterrows():
        text = row['Phrase'].split()
        stemmed_words = [stemmer.stem(word) for word in text]
        list_of_words.append(stemmed_words)
        text = " ".join(stemmed_words)
        row['Phrase'] = text
    data['list_of_words'] = list_of_words
    return dataset
data = lemmatization(data)
data
# Out:
#       Emotion                                             Phrase  \
# 0         joy  on day when i feel close to my partner and oth...
# 1        fear  everi time i imagin that someon i love or i co...
# 2       anger  when i had been obvious unjust treat and had n...
# 3     sadness  when i think about the short time that we live...
# 4     disgust  at a gather i found myself involuntarili sit n...
# 5       shame  when i realiz that i was direct the feel of di...
# 6       guilt  i feel guilti when when i realiz that i consid...
# 7         joy  after my girlfriend had taken her exam we went...
# 8        fear  when for the first time i realiz the mean of d...
# 9       anger  when a car is overtak anoth and i am forc to d...
# 10    sadness  when i recent thought about the hard work it t...
# 11    disgust       when i found a bristl in the liver past tube
# 12      shame  when i was tire and unmotiv i shout at my girl...
# 13      guilt  when i think that i do not studi enough after ...
# 14        joy  when i pass an examin which i did not think i ...
# 15       fear  when one has arrang to meet someon and that pe...
# 16      anger  when one is unjust accus of someth one has not...
# 17    sadness  when one studi seem hopeless difficult and uni...
# 18    disgust  when one find out that someon you know is not ...
# 19      shame  when one has been unjust stupid toward someon els
# 20      guilt  when one has neglect or been unjust to a good ...
# 21        joy              pass an exam i did not expect to pass
# 22       fear  when i climb up a tree to pick appl the angl o...
# 23      anger                             friend who tortur anim
# 24    sadness                                   same as in anger
# 25    disgust                             friend who tortur anim
# 26      shame                same as abov friend who tortur anim
# 27      guilt  when excus are necessari and i get out of do i...
# 28        joy                             when i had my children
# 29       fear  when my 2 year old son climb up and sat on the...
# ...       ...                                                ...
# 7622    shame  i forgot to zip up my trouser this was not not...
# 7623    guilt                                               peep
# 7624      joy  i had a picnic with old classmat we chat and p...
# 7625     fear  at night when i was alon at home all the famil...
# 7626    anger  when i saw that my bed at the hostel was a mes...
# 7627  sadness  dure the physic experi session i did not under...
# 7628  disgust  a man sexual aggress a small girl in the bus b...
# 7629    shame                   be unabl to stop urin on the bus
# 7630    guilt  there were old peopl in a crowd bus and i did ...
# 7631      joy  it was the first time that i gave a birthday p...
# 7632     fear  it was a week befor the higher level result we...
# 7633    anger  the surnam of my brother was differ from our h...
# 7634  sadness  when i was in primari 6 my father die i was ve...
# 7635  disgust  at hostel my roommat was a veri selfish person...
# 7636    shame  my friend had mani femal friend and i thought ...
# 7637    guilt  in the past i use to think that my mother was ...
# 7638      joy  in august1983 the long await big envelop a doc...
# 7639     fear  on christma eve1984 i had just finish the exam...
# 7640    anger  in septemb 1984 i was forc to live with someon...
# 7641  sadness  this issu worri me rather than sadden me in mi...
# 7642  disgust  my roommat like to listen to some meaningless ...
# 7643    shame  last summer i went camp with some cu student a...
# 7644    guilt                     i lie to one of my best friend
# 7645      joy            i receiv a letter from a distant friend
# 7646     fear  my parent were out and i was the eldest at hom...
# 7647    anger  two year back someon invit me to be the tutor ...
# 7648  sadness  i had taken the respons to do someth and i had...
# 7649  disgust  i was at home and i heard a loud sound of spit...
# 7650    shame  i did not do the homework that the teacher had...
# 7651    guilt  i had shout at my younger brother and he was a...
#
#                                           list_of_words
# 0     [on, day, when, i, feel, close, to, my, partne...
# 1     [everi, time, i, imagin, that, someon, i, love...
# 2     [when, i, had, been, obvious, unjust, treat, a...
# 3     [when, i, think, about, the, short, time, that...
# 4     [at, a, gather, i, found, myself, involuntaril...
# 5     [when, i, realiz, that, i, was, direct, the, f...
# 6     [i, feel, guilti, when, when, i, realiz, that,...
# 7     [after, my, girlfriend, had, taken, her, exam,...
# 8     [when, for, the, first, time, i, realiz, the, ...
# 9     [when, a, car, is, overtak, anoth, and, i, am,...
# 10    [when, i, recent, thought, about, the, hard, w...
# 11    [when, i, found, a, bristl, in, the, liver, pa...
# 12    [when, i, was, tire, and, unmotiv, i, shout, a...
# 13    [when, i, think, that, i, do, not, studi, enou...
# 14    [when, i, pass, an, examin, which, i, did, not...
# 15    [when, one, has, arrang, to, meet, someon, and...
# 16    [when, one, is, unjust, accus, of, someth, one...
# 17    [when, one, studi, seem, hopeless, difficult, ...
# 18    [when, one, find, out, that, someon, you, know...
# 19    [when, one, has, been, unjust, stupid, toward,...
# 20    [when, one, has, neglect, or, been, unjust, to...
# 21      [pass, an, exam, i, did, not, expect, to, pass]
# 22    [when, i, climb, up, a, tree, to, pick, appl, ...
# 23                          [friend, who, tortur, anim]
# 24                                [same, as, in, anger]
# 25                          [friend, who, tortur, anim]
# 26          [same, as, abov, friend, who, tortur, anim]
# 27    [when, excus, are, necessari, and, i, get, out...
# 28                         [when, i, had, my, children]
# 29    [when, my, 2, year, old, son, climb, up, and, ...
# ...                                                 ...
# 7622  [i, forgot, to, zip, up, my, trouser, this, wa...
# 7623                                             [peep]
# 7624  [i, had, a, picnic, with, old, classmat, we, c...
# 7625  [at, night, when, i, was, alon, at, home, all,...
# 7626  [when, i, saw, that, my, bed, at, the, hostel,...
# 7627  [dure, the, physic, experi, session, i, did, n...
# 7628  [a, man, sexual, aggress, a, small, girl, in, ...
# 7629          [be, unabl, to, stop, urin, on, the, bus]
# 7630  [there, were, old, peopl, in, a, crowd, bus, a...
# 7631  [it, was, the, first, time, that, i, gave, a, ...
# 7632  [it, was, a, week, befor, the, higher, level, ...
# 7633  [the, surnam, of, my, brother, was, differ, fr...
# 7634  [when, i, was, in, primari, 6, my, father, die...
# 7635  [at, hostel, my, roommat, was, a, veri, selfis...
# 7636  [my, friend, had, mani, femal, friend, and, i,...
# 7637  [in, the, past, i, use, to, think, that, my, m...
# 7638  [in, august1983, the, long, await, big, envelo...
# 7639  [on, christma, eve1984, i, had, just, finish, ...
# 7640  [in, septemb, 1984, i, was, forc, to, live, wi...
# 7641  [this, issu, worri, me, rather, than, sadden, ...
# 7642  [my, roommat, like, to, listen, to, some, mean...
# 7643  [last, summer, i, went, camp, with, some, cu, ...
# 7644            [i, lie, to, one, of, my, best, friend]
# 7645   [i, receiv, a, letter, from, a, distant, friend]
# 7646  [my, parent, were, out, and, i, was, the, elde...
# 7647  [two, year, back, someon, invit, me, to, be, t...
# 7648  [i, had, taken, the, respons, to, do, someth, ...
# 7649  [i, was, at, home, and, i, heard, a, loud, sou...
# 7650  [i, did, not, do, the, homework, that, the, te...
# 7651  [i, had, shout, at, my, younger, brother, and,...
#
# [7652 rows x 3 columns]

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Flatten, LSTM, Conv1D, MaxPooling1D, Dropout, Activation
from keras.layers.embeddings import Embedding
vocabulary_size = 20000
tokenizer = Tokenizer(num_words= vocabulary_size)
tokenizer.fit_on_texts(data['Phrase'])

sequences = tokenizer.texts_to_sequences(data['Phrase'])
tokenized_data = pad_sequences(sequences, maxlen=50)
# tokenized_data

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')
X = data['Emotion'].unique()
# print X
X=X.reshape(-1,1)
# print X
enc.fit(X)
enc.categories_
emotion_data=data['Emotion'].values
emotion_data=emotion_data.reshape(-1,1)
emotion_data=enc.transform(emotion_data).toarray()

# %%
train_phrase, validate_phrase = np.split(tokenized_data,[int(.8*len(tokenized_data))])
train_label,validate_emotion=np.split(emotion_data,[int(.8*len(emotion_data))])
# train_label
